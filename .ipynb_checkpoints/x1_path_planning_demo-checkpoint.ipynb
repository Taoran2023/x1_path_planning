# %%
import numpy as np
import matplotlib.pyplot as plt
from map_utils import RectRegion, CircleRegion, RegionManager, RegionTag

def make_base_map(H, W, base_cost=1.0, noise=0.0, seed=0):
    """
    create traversability map:
    - base_cost: base cost
    - noise: Noise amplitude (0:no noise)
    """
    rng = np.random.default_rng(seed)
    T = np.full((H, W), float(base_cost), dtype=float)
    if noise > 0:
        T = T + rng.normal(loc=0.0, scale=noise, size=(H, W))
        T = np.clip(T, 0.01, None)  
    return T

def plot_map(T, title="Traversability Map", show_inf_as_max=True):

    T_vis = T.copy()
    if show_inf_as_max:
        finite_vals = T_vis[np.isfinite(T_vis)]
        maxv = finite_vals.max() if finite_vals.size > 0 else 1.0
        T_vis[~np.isfinite(T_vis)] = maxv * 1.2

    plt.figure(figsize=(16, 16))
    im = plt.imshow(T_vis, origin="lower")
    plt.colorbar(im, fraction=0.046, pad=0.04)
    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.tight_layout()
    plt.show()

    
# ============ define Reigion============
rm = RegionManager()

# indoor rectangle
building1 = RectRegion(
    name="building1",
    tag=RegionTag.INDOOR,
    score=5.0,
    x0=0, y0=75,
    x1=75, y1=125
)
building2 = RectRegion(
    name="building2",
    tag=RegionTag.INDOOR,
    score=7.0,
    x0=50, y0=0,
    x1=75, y1=75
)

# outdoor area
yard = RectRegion(
    name="yard",
    tag=RegionTag.OUTDOOR,
    score=2.5,
    x0=125, y0=0,
    x1=200, y1=75
)

# no-traversable obstacle
turtlepound = RectRegion(
    name="turtlepound",
    tag=RegionTag.NO_TRAVERSABLE,
    score=float("inf"),
    x0=125, y0=75,
    x1=170, y1=200
)

# turtlepound = CircleRegion(
#     name="turtlepound",
#     tag=RegionTag.NO_TRAVERSABLE,
#     score=float("inf"),
#     cx=60, cy=60,
#     r=5
# )

rm.add_region(building1)
rm.add_region(building2)
rm.add_region(yard)
rm.add_region(turtlepound)



# ============ define door============

dm = RegionManager()

# building1
door1 = RectRegion(
    name="door1",
    tag=RegionTag.DOOR,
    score=10.0,
    x0=25, y0=122,
    x1=50, y1=127
)
door2 = RectRegion(
    name="door2",
    tag=RegionTag.DOOR,
    score=10.0,
    x0=10, y0=73,
    x1=30, y1=78
)
# building2
door3 = RectRegion(
    name="door3",
    tag=RegionTag.DOOR,
    score=10.0,
    x0=48, y0=15,
    x1=52, y1=35,
)
door4 = RectRegion(
    name="door4",
    tag=RegionTag.DOOR,
    score=10.0,
    x0=73, y0=15,
    x1=77, y1=35,
)
dm.add_region(door1)
dm.add_region(door2)
dm.add_region(door3)
dm.add_region(door4)
# Out:
# region added

# %%
# ============ create map============
H, W = 200, 200
T = make_base_map(H, W, base_cost=1.0, noise=0.5, seed=42)

# plot_map(T, title="Demo Traversability Map (with blocks + obstacle)")

# ============ add region============
for y in range(H):
    for x in range(W):     
        if rm.query_tag(x, y) !="unknown":
            T[y, x] = rm.query_score(x, y)
        if dm.query_tag(x, y) !="unknown":
            T[y, x] = dm.query_score(x, y)            
            
plot_map(T, title="Demo Traversability Map (with blocks + obstacle)")

# %%
def plot_region_masks(rm, region_name: str, res: float):
    """
    Visualize occupancy and boundary mask for a given region.
    """
    if region_name not in rm.occupancy_masks:
        raise ValueError(f"No occupancy mask for region {region_name}")
    if region_name not in rm.boundary_masks:
        raise ValueError(f"No boundary mask for region {region_name}")

    occ = rm.occupancy_masks[region_name]
    bnd = rm.boundary_masks[region_name]

    H, W = occ.shape
    extent = [0, W*res, 0, H*res]

    fig, axs = plt.subplots(1, 2, figsize=(12, 5))

    # Occupancy mask
    axs[0].imshow(occ, origin="lower", extent=extent)
    axs[0].set_title(f"Occupancy mask: {region_name}")
    axs[0].set_xlabel("x")
    axs[0].set_ylabel("y")

    # Boundary mask
    axs[1].imshow(bnd, origin="lower", extent=extent)
    axs[1].set_title(f"Boundary mask (4-neighborhood): {region_name}")
    axs[1].set_xlabel("x")
    axs[1].set_ylabel("y")

    plt.tight_layout()
    plt.show()
    
def plot_mask_with_geometry(rm, region_name, res):
    occ = rm.occupancy_masks[region_name]
    bnd = rm.boundary_masks[region_name]
    r = rm.get_region_by_name(region_name)

    H, W = occ.shape
    extent = [0, W*res, 0, H*res]

    fig, ax = plt.subplots(figsize=(6,6))
    ax.imshow(bnd, origin="lower", extent=extent, cmap="Reds")

    # Draw geometry outline
    if isinstance(r, RectRegion):
        xs = [r.x0, r.x1, r.x1, r.x0, r.x0]
        ys = [r.y0, r.y0, r.y1, r.y1, r.y0]
        ax.plot(xs, ys, "b-", lw=2)

    elif isinstance(r, CircleRegion):
        theta = np.linspace(0, 2*np.pi, 200)
        xs = r.cx + r.r * np.cos(theta)
        ys = r.cy + r.r * np.sin(theta)
        ax.plot(xs, ys, "b-", lw=2)

    ax.set_title(f"Boundary mask + geometry: {region_name}")
    ax.set_aspect("equal")
    plt.show()
    
width = 200
height = 200
res = 1 
rm.compute_boundary_masks(width, height, res, connectivity=4)
plot_region_masks(rm, "building1", res)
plot_region_masks(rm, "turtlepound", res)
# plot_mask_with_geometry(rm, "building1", res)
# plot_mask_with_geometry(rm, "building2", res)

# %%
from map_utils import RegionManager, RectRegion, CircleRegion, RegionTag
from graph_utils import NodeSampler, TAG_DOOR, GraphBuilderKNN

sampler = NodeSampler(width=200, height=200, region_manager=rm, door_manager=dm, rng_seed=42)

g = sampler.make_graph_with_nodes(
    n_random=430,
    n_door=8,
    min_dist=8.0,
    random_allowed_tags=["indoor", "outdoor","unknown", "no-traversable"]
)
# print(len(g), g.node_ids_by_tag.keys())
domain_tags = ["indoor", "outdoor", "unknown","no-traversable"]


# mask = rm.boundary_masks["turtlepound"]
# print("mask shape(H,W) =", mask.shape)
# print("boundary cells =", int(mask.sum()))
# H, W = mask.shape
# print("implied world size by mask+res:", W*1.0, H*1.0)
# print("sampler.W/H =", sampler.W, sampler.H)


# ============ add cross boundary portal node ============

added = sampler.add_portal_nodes_from_region_boundary(
    g,
    "turtlepound",
    n=25,
    res=1.0,
    min_dist=8,
    stride=1,
    door_tag="door",
    jitter=0.0,
)
added = sampler.add_portal_nodes_from_region_boundary(
    g,
    "yard",
    n=20,
    res=1.0,
    min_dist=8,
    stride=1,
    door_tag="door",
    jitter=0.0,
)


# ============ build KNN topo map ============

builder = GraphBuilderKNN(domain_tags=["indoor","outdoor","unknown","no-traversable"], portal_tag="door")
builder.build_edges(
    g, 
    k_intra=5, 
    k_portal=5, 
    r_max=15,
    r_max_portal=15)


print("nodes:", len(g.nodes), "edges:", len(g.edges))

print("portal edges:", len(g.edge_ids("portal")))
# Out:
# nodes: 483 edges: 1286
# portal edges: 259

# %%
from viz_utils import plot_graph_on_blank, plot_graph_on_costmap #,plot_graph_edges

# domain_colors = plot_graph_on_costmap(T, g, portal_color="black", edge_color_seed=42,figsize=(10,10))
# plot_graph_on_blank(g, width=200, domain_colors=domain_colors,height=200, edge_linewidth=3,figsize=(10,10))

# %%
from graph_utils import add_goal_anchor, Goal, connect_goals_to_graph
from viz_utils import plot_goal

start_goal = add_goal_anchor(
    g, rm=rm,
    goal_type_tag="start",
    pose=(15, 100),
    name="common start"
)

end_goal1 = add_goal_anchor(
    g, rm=rm,
    goal_type_tag="end",
    pose=(180, 160),
    name="m4 goal"
)

end_goal2 = add_goal_anchor(
    g, rm=rm,
    goal_type_tag="end",
    pose=(160, 25),
    name="humanonid goal"
)
print(start_goal, end_goal1, end_goal2)
print("start node tag =", g.nodes[start_goal.node_id].tag)
print("goal1  node tag =", g.nodes[end_goal1.node_id].tag)
print("goal2  node tag =", g.nodes[end_goal2.node_id].tag)

# domain_colors1 = plot_graph_on_costmap(T, g, portal_color="black", edge_color_seed=42,figsize=(10,10),goals=[start_goal, end_goal1,end_goal2],)
# domain_colors2 = plot_graph_on_blank(g, width=200, domain_colors=domain_colors1,height=200, edge_linewidth=3,figsize=(10,10),goals=[start_goal, end_goal1,end_goal2],)
# Out:
# Goal(type_tag='start', pose=(15.0, 100.0), node_id=483, name='common start') Goal(type_tag='end', pose=(180.0, 160.0), node_id=484, name='m4 goal') Goal(type_tag='end', pose=(160.0, 25.0), node_id=485, name='humanonid goal')
# start node tag = indoor
# goal1  node tag = unknown
# goal2  node tag = outdoor

# %%
connect_goals_to_graph(
    g,
    goals=[start_goal, end_goal1,end_goal2],
    r=20.0,    # radius
    k=8,       # maximum connecting edge
    etype="anchor",
)
domain_colors1 = plot_graph_on_costmap(T, g, portal_color="black", edge_color_seed=42,figsize=(10,10),goals=[start_goal, end_goal1,end_goal2],)
domain_colors2 = plot_graph_on_blank(g, width=200, domain_colors=domain_colors1,height=200, edge_linewidth=3,figsize=(10,10),goals=[start_goal, end_goal1,end_goal2],)

# %%
#  define agent and energy model

from agent import Agent, EnergyModel, ModelTag


def debug_print_agent(agent: Agent):
    print("=" * 60)
    print(f"Agent name        : {agent.name}")
    print(f"Energy budget     : {agent.energy_budget}")
    print(f"Supported models  : {agent.models}")
    print(f"No-traversable tags: {list(agent.no_traversable_tags)}")
    print(f"Transform energy  : {agent.transform_energy}")
    print()

    print("Energy Models:")
    for model, em in agent.energy_models.items():
        print(f"  - Model: {model}")
        print(f"      energy_model_tag : {em.energy_model_tag}")
        print(f"      energy_factors   : {em.energy_factors}")
        print(f"      region_factors   : {em.region_factors}")
        print(f"      score_mode       : {em.score_mode}")
        print(f"      score_params     : {em.score_params}")
        print(f"      edge_type_factors: {em.edge_type_factors}")
    print("=" * 60)
    print()


# ====================================================================================================
# Define Energy Models
# ====================================================================================================

# Ground robot (UGV / legged) linear energy
ugv_energy = EnergyModel(
    model=ModelTag.UGV,
    energy_model_tag="linear",
    energy_factors={
        "a": 5.0,     # linear coefficient
        "b": 0.0,
    },
    region_factors={
        "outdoor": 1.0,
        "indoor": 1.2,
        "unknown": 1.5,
    },
)

# UAV energy model (flying over water etc.)
uav_energy = EnergyModel(
    model=ModelTag.UAV,
    energy_model_tag="linear",
    energy_factors={
        "a": 10.0,     # higher per meter (flying)
        "b": 0.0,
    },
    region_factors={
        "no-traversable": 1.0,   # water region, allowed for UAV
        "outdoor": 0.8,
        "unknown": 1.0,
    },
)

# G1 LEGGED energy model
legged_energy = EnergyModel(
    model=ModelTag.LEGGED,
    energy_model_tag="linear",
    energy_factors={
        "a": 6.0,     #  legged
        "b": 0.0,
    },
    region_factors={
        "outdoor": 1.0,
        "indoor": 1.2,
        "unknown": 1.5,
    },
)

# G1M4 LEGGED energy model(G1 carring m4, higher energy a cost)
G1M4_legged_energy = EnergyModel(
    model=ModelTag.LEGGED,
    energy_model_tag="linear",
    energy_factors={
        "a": 10.0,     # higher per meter (G1 carring m4)
        "b": 0.0,
    },
    region_factors={
        "outdoor": 1.0,
        "indoor": 1.2,
        "unknown": 1.5,
    },
)

# ====================================================================================================
# Define Agent
# ====================================================================================================

# ====================================================================================================
# Experiment testing----M4----G1---G1M4
# good for range vis: 1100, 1500, 1500
# good for all field: 2500, 2500, 2500
#
# ====================================================================================================
M4_agent = Agent(
    name="M4",
    models=[ModelTag.UGV, ModelTag.UAV],
    energy_models={
        ModelTag.UGV: ugv_energy,
        ModelTag.UAV: uav_energy,
    },
    energy_budget=1100.0,
    transform_energy=5.0,   # demo: ignore transform
    no_traversable_tags=set(),  # handled via rules instead
)

G1_agent = Agent(
    name="G1",
    models=[ModelTag.LEGGED],
    energy_models={
        ModelTag.LEGGED: legged_energy,
    },
    energy_budget=1500.0,
    transform_energy=0.0,   # demo: ignore transform
    no_traversable_tags=set(),  # handled via rules instead
)

G1M4_agent = Agent(
    name="G1M4",
    models=[ModelTag.LEGGED],
    energy_models={
        ModelTag.LEGGED: G1M4_legged_energy,
    },
    energy_budget=1500.0,
    transform_energy=0.0,   # demo: ignore transform
    no_traversable_tags=set(),  # handled via rules instead
)
# =========================
# Debug print
# =========================
debug_print_agent(M4_agent)
debug_print_agent(G1_agent)
debug_print_agent(G1M4_agent)
# Out:
# ...
# Agent name        : M4
# Energy budget     : 1100.0
# Supported models  : ['UGV', 'UAV']
# No-traversable tags: []
# Transform energy  : 5.0
#
# Energy Models:
#   - Model: UGV
#       energy_model_tag : linear
#       energy_factors   : {'a': 5.0, 'b': 0.0}
#       region_factors   : {'outdoor': 1.0, 'indoor': 1.2, 'unknown': 1.5}
#       score_mode       : ignore
#       score_params     : {}
#       edge_type_factors: {}
#   - Model: UAV
#       energy_model_tag : linear
#       energy_factors   : {'a': 10.0, 'b': 0.0}
#       region_factors   : {'no-traversable': 1.0, 'outdoor': 0.8, 'unknown': 1.0}
#       score_mode       : ignore
#       score_params     : {}
#       edge_type_factors: {}
# ...
#
# ...
# Agent name        : G1
# Energy budget     : 1500.0
# Supported models  : ['legged']
# No-traversable tags: []
# Transform energy  : 0.0
#
# Energy Models:
#   - Model: legged
#       energy_model_tag : linear
#       energy_factors   : {'a': 6.0, 'b': 0.0}
# ...

# %%
rules = {
    "outdoor": ["UGV", "legged"],
    "indoor":  ["legged"],
    "unknown": ["UGV", "legged"],

    # water / lake / river
    "no-traversable": ["UAV"],

    # door / boundary / anchor 节点
    # 一般允许和相邻区域一致，或允许全部
    "door": ["UGV", "legged", "UAV"],
}

from tree_search import dijkstra_budget_expand

M4_tree = dijkstra_budget_expand(
    g,
    root_goal=end_goal1,
    agent=M4_agent,
    rules=rules,
    budget_energy=M4_agent.energy_budget,   # 或显式给一个数
    cost_cfg=None,                        # demo 阶段可不传
)

G1_tree = dijkstra_budget_expand(
    g,
    root_goal=end_goal2,
    agent=G1_agent,
    rules=rules,
    budget_energy=G1_agent.energy_budget,   # 或显式给一个数
    cost_cfg=None,                        # demo 阶段可不传
)

G1M4_tree = dijkstra_budget_expand(
    g,
    root_goal=start_goal,
    agent=G1M4_agent,
    rules=rules,
    budget_energy=G1M4_agent.energy_budget,   # 或显式给一个数
    cost_cfg=None,                        # demo 阶段可不传
)

# %%
from viz_utils import plot_tree_on_blank, plot_tree_on_costmap


plot_tree_on_blank(g, M4_tree, width=200, height=200, base_edge_alpha = 0.8, title="Dijkstra Tree (blank)")
plot_tree_on_blank(g, G1_tree, width=200, height=200, base_edge_alpha = 0.8,title="Dijkstra Tree (blank)")
plot_tree_on_blank(g, G1M4_tree, width=200, height=200, base_edge_alpha = 0.8,title="Dijkstra Tree (blank)")

# %%
plot_tree_on_costmap(T, g, M4_tree, title="Dijkstra Tree (costmap)")
plot_tree_on_costmap(T, g, G1_tree, title="Dijkstra Tree (costmap)")
plot_tree_on_costmap(T, g, G1M4_tree, title="Dijkstra Tree (costmap)")

# %%
# debug recover_path

# 任选一个可达节点（比如能量最大的/最远的一个）
# target = max(M4_tree.energy_cost, key=lambda nid: M4_tree.energy_cost[nid])

# from tree_search import recover_path
# path = recover_path(g, M4_tree, target)

# print("Recovered path nodes:", len(path.nodes))
# print("Total energy:", path.total_energy)
# print("Models along path:", set(path.models))


# from viz_utils import plot_path_on_blank, plot_path_on_costmap

# plot_path_on_blank(
#     g, path,
#     width=200, height=200,
#     show_tree=True, tree=M4_tree,
#     title="Tree + recovered path (blank)"
# )

# plot_path_on_costmap(
#     T, g, path,
#     show_tree=True, tree=M4_tree,
#     title="Tree + recovered path (costmap)"
# )

# %%
from typing import List, Set, Tuple

def overlap_nodes_from_trees(trees: List) -> Set[int]:
    """
    Intersection of settled nodes across all trees.
    Each tree must have: tree.settled_nodes (set[int]).
    """
    if not trees:
        return set()

    overlap = set(trees[0].settled_nodes)
    for t in trees[1:]:
        overlap &= set(t.settled_nodes)
    return overlap

def rank_overlap_nodes_by_total_energy(trees: List, overlap_nodes: Set[int]) -> List[Tuple[int, float]]:
    """
    For each node in overlap_nodes, compute sum(tree.energy_cost[node]) across all trees.
    Returns sorted list: [(node_id, total_energy), ...] (ascending).
    """
    ranked = []
    for nid in overlap_nodes:
        total = 0.0
        ok = True
        for t in trees:
            ec = t.energy_cost.get(nid, None)
            if ec is None:
                ok = False
                break
            total += float(ec)
        if ok:
            ranked.append((nid, total))
    ranked.sort(key=lambda x: x[1])
    return ranked

# %%
trees = [M4_tree, G1_tree, G1M4_tree]
overlap_nodes = overlap_nodes_from_trees(trees)

print("overlap nodes =", len(overlap_nodes))


ranked = rank_overlap_nodes_by_total_energy(trees, overlap_nodes)
print("best overlap node (min sum energy):", ranked[0] if ranked else None)
# Out:
# overlap nodes = 31
# best overlap node (min sum energy): (116, 3040.9658219216617)

# %%
from tree_search import recover_path


target = ranked[0][0]
M4_path = recover_path(g, M4_tree, target)
G1_path = recover_path(g, G1_tree, target)
G1M4_path = recover_path(g, G1M4_tree, target)

# %%
from viz_utils import plot_multi_tree_overlap_paths


trees = [M4_tree, G1_tree, G1M4_tree]
paths = [M4_path, G1_path, G1M4_path]
goals = [start_goal, end_goal1, end_goal2]

best_node = ranked[0][0]

plot_multi_tree_overlap_paths(
    g,
    width=200,
    height=200,
#     costmap=T,                 # 没有就传 None
    trees=trees,
    tree_labels=["M4", "G1", "G1M4"],
    tree_colors=["tab:green", "tab:orange", "tab:purple"],

    overlap_nodes=overlap_nodes,
    overlap_ranked=ranked,           # 用于 energy 上色 + best node 默认取 ranked[0]
    best_overlap_node=best_node,     # 也可不传，让函数自己取 ranked[0]

    paths=paths,
    path_labels=["M4", "G1", "G1M4"],
    path_colors=["tab:red", "tab:blue", "tab:brown"],

    goals=goals,

    # style knobs
    base_edge_alpha=0.05,
    base_edge_lw=3.2,

    tree_alpha=0.822,
    tree_lw=1.6,

    path_alpha=0.95,
    path_lw=3.2,

    overlap_point_size=100,
    overlap_alpha=0.85,
    overlap_cmap="viridis",
    overlap_use_log=False,
    overlap_colorbar=True,

    best_overlap_size = 500,
    goal_size = 160.0,

    
    show_colorbar=True,
    title="Trees + overlap (energy-colored) + paths + goals",
    legend=True,
    
    figsize = [15, 15],
    
    font_cfg={
        "title": 16,
        "label": 14,
        "tick": 12,
        "legend": 12,
        "text": 20,
    },
)

# %%
plot_multi_tree_overlap_paths(
    g,
    width=200,
    height=200,
    costmap=T,                 # 没有就传 None
    trees=trees,
    tree_labels=["M4", "G1", "G1M4"],
    tree_colors=["tab:green", "tab:orange", "tab:purple"],

    overlap_nodes=overlap_nodes,
    overlap_ranked=ranked,           # 用于 energy 上色 + best node 默认取 ranked[0]
    best_overlap_node=best_node,     # 也可不传，让函数自己取 ranked[0]

    paths=paths,
    path_labels=["M4", "G1", "G1M4"],
    path_colors=["tab:red", "tab:blue", "tab:brown"],

    goals=goals,

    # style knobs
    base_edge_alpha=0.05,
    base_edge_lw=3.2,

    tree_alpha=0.822,
    tree_lw=1.6,

    path_alpha=0.95,
    path_lw=7.2,

    overlap_point_size=100,
    overlap_alpha=0.85,
    overlap_cmap="viridis",
    overlap_use_log=False,
    overlap_colorbar=True,

    best_overlap_size = 500,
    goal_size = 160.0,

    
    show_colorbar=True,
    title="Trees + overlap (energy-colored) + paths + goals",
    legend=True,
    
    figsize = [15, 15],
    
    font_cfg={
        "title": 16,
        "label": 14,
        "tick": 12,
        "legend": 12,
        "text": 20,
    },
)

# %%
from viz_utils import plot_path_on_blank, plot_path_on_costmap


plot_path_on_blank(
    g, M4_path,
    width=200, height=200,
    show_tree=True, tree=M4_tree,
    title="Tree + recovered path (blank)"
)
plot_path_on_blank(
    g, G1_path,
    width=200, height=200,
    show_tree=True, tree=G1_tree,
    title="Tree + recovered path (blank)"
)
plot_path_on_blank(
    g, G1M4_path,
    width=200, height=200,
    show_tree=True, tree=G1M4_tree,
    title="Tree + recovered path (blank)"
)
# plot_path_on_costmap(
#     T, g, path,
#     show_tree=True, tree=M4_tree,
#     title="Tree + recovered path (costmap)"
# )
